# %% [markdown]
# # Supply Chain Disruption Risk & Spoilage Prediction Model
# This notebook trains a predictive Machine Learning model for supply chain disruption risk scoring.

# %%
import numpy as np
import pandas as pd
print('Notebook environment initialized for Supply Chain ML Models')
